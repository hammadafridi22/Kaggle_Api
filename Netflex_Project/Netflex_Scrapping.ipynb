# %%
# !pip install kaggle
import kaggle

# !kaggle datasets download shivamb/netflix-shows -f netflix_titles.csv
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/shivamb/netflix-shows
# License(s): CC0-1.0
# netflix_titles.csv.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
#extract file from zip file
import zipfile
zip_ref = zipfile.ZipFile('netflix_titles.csv.zip') 
zip_ref.extractall() # extract file to dir
zip_ref.close() # close file

# %%
import pandas as pd 
df = pd.read_csv('netflix_titles.csv')

# %%
#load the data into sql server using replace option
import sqlalchemy as sal
engine = sal.create_engine('mssql://HAMMAD-AFRIDI/master?driver=ODBC+DRIVER+17+FOR+SQL+SERVER')
conn=engine.connect()

# %%
df.to_sql('netflix_raw', con=conn , index=False, if_exists = 'append')
conn.close()
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# File c:\Users\Hammad Afridi\.kaggle\kaggle_api\env\Lib\site-packages\sqlalchemy\engine\base.py:2125, in Connection._exec_insertmany_context(self, dialect, context)
#    2124     else:
# -> 2125         dialect.do_execute(
#    2126             cursor,
#    2127             sub_stmt,
#    2128             sub_params,
#    2129             context,
#    2130         )
#    2132 except BaseException as e:
#
# File c:\Users\Hammad Afridi\.kaggle\kaggle_api\env\Lib\site-packages\sqlalchemy\engine\default.py:952, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     951 def do_execute(self, cursor, statement, parameters, context=None):
# --> 952     cursor.execute(statement, parameters)
#
# ...

# %%
df[df.show_id=='s5023']
# Out:
#      show_id   type    title       director           cast      country  \
# 5022   s5023  Movie  반드시 잡는다  Hong-seon Kim  Baek Yoon-sik  South Korea
#
#              date_added  release_year rating duration  \
# 5022  February 28, 2018          2017  TV-MA  110 min
#
#                                     listed_in  \
# 5022  Dramas, International Movies, Thrillers
#
#                                             description
# 5022  After people in his town start turning up dead...

# %%
max(df.description.dropna().str.len())
# Out:
# 248
